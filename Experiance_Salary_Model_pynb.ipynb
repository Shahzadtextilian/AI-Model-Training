# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahzadtextilian/AI-Model-Training/blob/master/Experiance_Salary_Model_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("/content/drive/MyDrive/Experience-Salary.csv")
df.rename(columns={'exp(in months)':'experience_months','salary(in thousands)':'salary_thousands'},inplace=True)

#df.drop(["Car ID"], axis=1, inplace=True)
df
# Out:
#      experience_months  salary_thousands
# 0            18.290293         16.521825
# 1            17.023407         11.666234
# 2            26.343613         23.167255
# 3            19.105834         20.877145
# 4            27.742516         23.166236
# ..                 ...               ...
# 995          22.161741         24.666502
# 996          32.266497         24.160270
# 997          17.039030         19.903797
# 998          25.222124         21.974413
# 999          16.418028         19.634787
#
# [1000 rows x 2 columns]

# %%
x=df[["experience_months"]]
y=df[["salary_thousands"]]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
len(x_train), len(x_test), len(y_train), len(y_test)
# Out:
# (800, 200, 800, 200)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#test the model
lr.predict(x_test)

# %%
lr.score(x_test,y_test)
# Out:
# 0.6999555673728632

# %%
import numpy as np

# Reshape x_train and y_train for gradient descent if they are pandas DataFrames
x_train_gd = x_train.values.flatten()
y_train_gd = y_train.values.flatten()

# Initialize parameters
m = 0 # slope
b = 0 # intercept

# Hyperparameters
learning_rate = 0.001
iterations = 10000

n = len(x_train_gd) # Number of training examples

# Gradient Descent function
def gradient_descent(x, y, m, b, learning_rate, iterations):
    costs = []
    for i in range(iterations):
        # Calculate predictions
        y_pred = m * x + b

        # Calculate gradients
        dm = (-2/n) * np.sum(x * (y - y_pred))
        db = (-2/n) * np.sum(y - y_pred)

        # Update parameters
        m = m - learning_rate * dm
        b = b - learning_rate * db

        # Calculate and store cost (Mean Squared Error)
        cost = (1/n) * np.sum(np.square(y - y_pred))
        costs.append(cost)

        if i % 1000 == 0:
            print(f"Iteration {i}: Cost = {cost:.4f}, m = {m:.4f}, b = {b:.4f}")

    return m, b, costs

# Run Gradient Descent
m_gd, b_gd, costs = gradient_descent(x_train_gd, y_train_gd, m, b, learning_rate, iterations)

print(f"\nFinal parameters after Gradient Descent: m = {m_gd:.4f}, b = {b_gd:.4f}")

# Make predictions on test set using GD parameters
x_test_gd = x_test.values.flatten()
y_pred_gd = m_gd * x_test_gd + b_gd

# Evaluate the model (Mean Squared Error on test set)
mse_gd = np.mean(np.square(y_test.values.flatten() - y_pred_gd))
print(f"Mean Squared Error on Test Set (Gradient Descent): {mse_gd:.4f}")

# Compare with LinearRegression from sklearn if needed
print(f"\nLinearRegression (sklearn) coefficients: m = {lr.coef_[0][0]:.4f}, b = {lr.intercept_[0]:.4f}")
# Out:
# Iteration 0: Cost = 793.1060, m = 1.5095, b = 0.0534
# Iteration 1000: Cost = 29.8682, m = 0.9740, b = 1.0355
# Iteration 2000: Cost = 29.1993, m = 0.9457, b = 1.8514
# Iteration 3000: Cost = 28.7536, m = 0.9226, b = 2.5173
# Iteration 4000: Cost = 28.4567, m = 0.9037, b = 3.0610
# Iteration 5000: Cost = 28.2588, m = 0.8884, b = 3.5047
# Iteration 6000: Cost = 28.1269, m = 0.8758, b = 3.8669
# Iteration 7000: Cost = 28.0391, m = 0.8655, b = 4.1626
# Iteration 8000: Cost = 27.9805, m = 0.8572, b = 4.4040
# Iteration 9000: Cost = 27.9415, m = 0.8503, b = 4.6010
#
# Final parameters after Gradient Descent: m = 0.8448, b = 4.7617
# Mean Squared Error on Test Set (Gradient Descent): 22.3813
#
# LinearRegression (sklearn) coefficients: m = 0.8200, b = 5.4764

# %%
import ipywidgets as widgets
from IPython.display import display
import pandas as pd

# Create a header
header = widgets.HTML("<h2>Salary Prediction UI</h2>")

# Create an input slider for experience in months
experience_input = widgets.FloatSlider(
    value=df['experience_months'].mean(),
    min=df['experience_months'].min(),
    max=df['experience_months'].max(),
    step=0.1,
    description='Experience (Months):',
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='400px')
)

# Output area for the prediction
output_text = widgets.Label(value="")

def predict_salary(change):
    # Create a DataFrame to match the feature names the model was trained on
    # This resolves the UserWarning about feature names
    exp_df = pd.DataFrame([[change['new']]], columns=['experience_months'])
    prediction = lr.predict(exp_df)[0][0]
    output_text.value = f"Predicted Salary: ${prediction:.2f}k"

# Observe changes in the slider
experience_input.observe(predict_salary, names='value')

# Initialize prediction
initial_exp_df = pd.DataFrame([[experience_input.value]], columns=['experience_months'])
initial_prediction = lr.predict(initial_exp_df)[0][0]
output_text.value = f"Predicted Salary: ${initial_prediction:.2f}k"

# Display the UI components
display(header, experience_input, output_text)
# Out:
# HTML(value='<h2>Salary Prediction UI</h2>')
# FloatSlider(value=26.15782467853106, description='Experience (Months):', layout=Layout(width='400px'), max=49.…
# Label(value='Predicted Salary: $26.93k')
